# %%
import circuits
from matplotlib import pyplot as plt
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact

# %% [markdown]
# Set the config

# %%
input_qubit_number = 4
max_gate_number = 10
batch_calculation_number = 1000
thread_number=28

# %% [markdown]
# Run the random circuit sampling

# %%
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-11 12:01:08.987758] 1000|100
# [2024-08-11 12:01:09.201905] 1000|200
# [2024-08-11 12:01:09.347905] 1000|300
# [2024-08-11 12:01:09.523905] 1000|400
# [2024-08-11 12:01:09.683905] 1000|500
# [2024-08-11 12:01:09.853135] 1000|600
# [2024-08-11 12:01:10.028135] 1000|700
# [2024-08-11 12:01:10.150135] 1000|800
# [2024-08-11 12:01:10.280136] 1000|900
# [2024-08-11 12:01:10.431135] 1000|1000
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.001652

# %% [markdown]
# Show P(F)

# %%
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)

# %% [markdown]
# Try langer batch number

# %%
batch_calculation_number *= 10
f_list = circuits.rcs_multi_thread(input_qubit_number,max_gate_number,batch_calculation_number,thread_number,True)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-11 12:01:10.733224] thread_number: 28
# [2024-08-11 12:01:12.836226] 10000|1000
# [2024-08-11 12:01:12.836226] 10000|1000
# [2024-08-11 12:01:13.791367] 10000|6000
# [2024-08-11 12:01:13.791367] 10000|6000
# [2024-08-11 12:01:13.979496] 10000|7000
# [2024-08-11 12:01:13.979496] 10000|7000
# [2024-08-11 12:01:14.357496] 10000|9000
# [2024-08-11 12:01:14.357496] 10000|9000
# [2024-08-11 12:01:14.357496] 10000|9000
# [2024-08-11 12:01:14.612496] 10000|10000
# [2024-08-11 12:01:15.120508] (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.000439

# %%
batch_calculation_number *= 10
f_list = circuits.rcs_multi_thread(input_qubit_number,max_gate_number,batch_calculation_number,thread_number,True)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-11 12:01:15.363512] thread_number: 28
# [2024-08-11 12:01:23.000211] 100000|30000
# [2024-08-11 12:01:23.001211] 100000|30000
# [2024-08-11 12:01:32.868076] 100000|70000
# [2024-08-11 12:01:35.134679] 100000|80000
# [2024-08-11 12:01:35.134679] 100000|80000
# [2024-08-11 12:01:35.134679] 100000|80000
# [2024-08-11 12:01:37.888205] 100000|90000
# [2024-08-11 12:01:40.885552] 100000|100000
# [2024-08-11 12:01:46.385931] (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.000310

# %% [markdown]
# Try to set more gates in the circuit

# %%
max_gate_number *= 10
f_list = circuits.rcs_multi_thread(input_qubit_number,max_gate_number,batch_calculation_number,thread_number,True)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-11 12:01:46.815932] thread_number: 28
# [2024-08-11 12:02:09.630502] 100000|10000
# [2024-08-11 12:02:30.294834] 100000|20000
# [2024-08-11 12:02:48.564826] 100000|30000
# [2024-08-11 12:03:06.116106] 100000|40000
# [2024-08-11 12:03:23.672438] 100000|50000
# [2024-08-11 12:03:41.530550] 100000|60000
# [2024-08-11 12:03:58.961366] 100000|70000
# [2024-08-11 12:04:16.388471] 100000|80000
# [2024-08-11 12:04:16.388471] 100000|80000
# [2024-08-11 12:04:33.944243] 100000|90000
# [2024-08-11 12:05:05.137081] 100000|100000
# [2024-08-11 12:05:10.588440] (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.002038

# %%
max_gate_number *= 10
f_list = circuits.rcs_multi_thread(input_qubit_number,max_gate_number,batch_calculation_number,thread_number,True)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-11 12:05:11.045719] thread_number: 28
# [2024-08-11 12:08:02.307108] 100000|10000
# [2024-08-11 12:10:54.759154] 100000|20000
# [2024-08-11 12:13:43.412190] 100000|30000
# [2024-08-11 12:16:33.082745] 100000|40000
# [2024-08-11 12:19:22.916438] 100000|50000
# [2024-08-11 12:22:13.269075] 100000|60000
# [2024-08-11 12:25:14.246974] 100000|70000
# [2024-08-11 12:28:04.920007] 100000|80000
# [2024-08-11 12:30:54.504483] 100000|90000
# [2024-08-11 12:34:03.244129] 100000|100000
# [2024-08-11 12:34:08.431692] (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.017374

# %% [markdown]
# Show P_Haar(F)

# %%
interact(circuits.show_p_haar_f, input_n=widgets.IntSlider(value=input_qubit_number,min=1,max=10,step=1,description='input_qubit:'))
# Out:
# interactive(children=(IntSlider(value=4, description='input_qubit:', max=10, min=1), Output()), _dom_classes=(…
# <function circuits.show_p_haar_f(input_n=1)>
