# %%
import circuits
from matplotlib import pyplot as plt
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact

# %% [markdown]
# Set the config

# %%
input_qubit_number = 3
max_gate_number = 10
batch_calculation_number = 1

# %% [markdown]
# Run the random circuit sampling

# %%
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.001995

# %% [markdown]
# Show P(F)

# %%
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)

# %% [markdown]
# Try langer batch number

# %%
batch_calculation_number *= 10
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 21:29:35.612528] 10|1
# [2024-08-09 21:29:35.615519] 10|2
# [2024-08-09 21:29:35.617514] 10|3
# [2024-08-09 21:29:35.619509] 10|4
# [2024-08-09 21:29:35.623498] 10|5
# [2024-08-09 21:29:35.626489] 10|6
# [2024-08-09 21:29:35.629481] 10|7
# [2024-08-09 21:29:35.631476] 10|8
# [2024-08-09 21:29:35.633471] 10|9
# [2024-08-09 21:29:35.637460] 10|10
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.003191

# %%
batch_calculation_number *= 10
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 21:29:35.946633] 100|10
# [2024-08-09 21:29:35.967578] 100|20
# [2024-08-09 21:29:35.991513] 100|30
# [2024-08-09 21:29:36.015449] 100|40
# [2024-08-09 21:29:36.038388] 100|50
# [2024-08-09 21:29:36.062324] 100|60
# [2024-08-09 21:29:36.084265] 100|70
# [2024-08-09 21:29:36.110196] 100|80
# [2024-08-09 21:29:36.131174] 100|90
# [2024-08-09 21:29:36.153140] 100|100
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.002334

# %% [markdown]
# Try to set more gates in the circuit

# %%
max_gate_number *= 10
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 21:29:36.562045] 100|10
# [2024-08-09 21:29:36.734583] 100|20
# [2024-08-09 21:29:36.941094] 100|30
# [2024-08-09 21:29:37.109643] 100|40
# [2024-08-09 21:29:37.272208] 100|50
# [2024-08-09 21:29:37.476662] 100|60
# [2024-08-09 21:29:37.650197] 100|70
# [2024-08-09 21:29:37.818281] 100|80
# [2024-08-09 21:29:38.012280] 100|90
# [2024-08-09 21:29:38.178375] 100|100
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.017679

# %%
max_gate_number *= 10
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 21:29:39.850633] 100|10
# [2024-08-09 21:29:41.091478] 100|20
# [2024-08-09 21:29:42.715296] 100|30
# [2024-08-09 21:29:44.838774] 100|40
# [2024-08-09 21:29:46.395773] 100|50
# [2024-08-09 21:29:48.419483] 100|60
# [2024-08-09 21:29:50.107095] 100|70
# [2024-08-09 21:29:51.953386] 100|80
# [2024-08-09 21:29:53.587196] 100|90
# [2024-08-09 21:29:55.289809] 100|100
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.168526

# %% [markdown]
# Show P_Haar(F)

# %%
interact(circuits.show_p_haar_f, input_n=widgets.IntSlider(value=input_qubit_number,min=1,max=10,step=1,description='input_qubit:'))
# Out:
# interactive(children=(IntSlider(value=3, description='input_qubit:', max=10, min=1), Output()), _dom_classes=(…
# <function circuits.show_p_haar_f(input_n=1)>
