# %%
import circuits
from matplotlib import pyplot as plt
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact

# %% [markdown]
# Set the config

# %%
input_qubit_number = 3
max_gate_number = 10
batch_calculation_number = 1

# %% [markdown]
# Run the random circuit sampling

# %%
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.017940

# %% [markdown]
# Show P(F)

# %%
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)

# %% [markdown]
# Try langer batch number

# %%
batch_calculation_number *= 10
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 21:11:42.394645] 10|1
# [2024-08-09 21:11:42.396639] 10|2
# [2024-08-09 21:11:42.397635] 10|3
# [2024-08-09 21:11:42.398632] 10|4
# [2024-08-09 21:11:42.399628] 10|5
# [2024-08-09 21:11:42.399628] 10|6
# [2024-08-09 21:11:42.402619] 10|7
# [2024-08-09 21:11:42.402619] 10|8
# [2024-08-09 21:11:42.403615] 10|9
# [2024-08-09 21:11:42.404612] 10|10
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.001296

# %%
batch_calculation_number *= 10
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 21:11:42.590011] 100|10
# [2024-08-09 21:11:42.605957] 100|20
# [2024-08-09 21:11:42.619910] 100|30
# [2024-08-09 21:11:42.635857] 100|40
# [2024-08-09 21:11:42.644828] 100|50
# [2024-08-09 21:11:42.654794] 100|60
# [2024-08-09 21:11:42.665757] 100|70
# [2024-08-09 21:11:42.678714] 100|80
# [2024-08-09 21:11:42.690674] 100|90
# [2024-08-09 21:11:42.699644] 100|100
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.001276

# %% [markdown]
# Try to set more gates in the circuit

# %%
max_gate_number *= 10
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 21:11:42.957581] 100|10
# [2024-08-09 21:11:43.060238] 100|20
# [2024-08-09 21:11:43.201885] 100|30
# [2024-08-09 21:11:43.341418] 100|40
# [2024-08-09 21:11:43.436226] 100|50
# [2024-08-09 21:11:43.505993] 100|60
# [2024-08-09 21:11:43.605659] 100|70
# [2024-08-09 21:11:43.717286] 100|80
# [2024-08-09 21:11:43.825922] 100|90
# [2024-08-09 21:11:43.935555] 100|100
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.010915

# %%
max_gate_number *= 10
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 21:11:44.973267] 100|10
# [2024-08-09 21:11:46.173425] 100|20
# [2024-08-09 21:11:47.375521] 100|30
# [2024-08-09 21:11:48.628615] 100|40
# [2024-08-09 21:11:49.791147] 100|50
# [2024-08-09 21:11:51.149858] 100|60
# [2024-08-09 21:11:52.258494] 100|70
# [2024-08-09 21:11:53.480547] 100|80
# [2024-08-09 21:11:54.668983] 100|90
# [2024-08-09 21:11:55.521299] 100|100
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.114243

# %% [markdown]
# Show P_Haar(F)

# %%
interact(circuits.show_p_haar_f, input_n=widgets.IntSlider(value=input_qubit_number,min=0,max=25,step=1,description='input_qubit:'))
widgets.IntSlider(value=input_qubit_number,min=0,max=25,step=1,description='input_qubit:')
# Out:
# interactive(children=(IntSlider(value=3, description='input_qubit:', max=25), Output()), _dom_classes=('widget…
# IntSlider(value=3, description='input_qubit:', max=25)
