# %%
import circuits

# %% [markdown]
# Set the config

# %%
input_qubit_number = 3
max_gate_number = 20
batch_calculation_number = 10000

# %% [markdown]
# Run the random circuit sampling

# %%
f_list = circuits.rcs(input_qubit_number,max_gate_number,batch_calculation_number)
# Out:
# [2024-08-09 09:52:20.425921] 10000|1000
# [2024-08-09 09:52:25.038031] 10000|2000
# [2024-08-09 09:52:30.161692] 10000|3000
# [2024-08-09 09:52:35.652417] 10000|4000
# [2024-08-09 09:52:41.086234] 10000|5000
# [2024-08-09 09:52:45.696301] 10000|6000
# [2024-08-09 09:52:50.284622] 10000|7000
# [2024-08-09 09:52:55.309651] 10000|8000
# [2024-08-09 09:53:00.639242] 10000|9000
# [2024-08-09 09:53:06.594678] 10000|10000
# (2 circuits per batch) avg_batch_running_time[hh:mm:ss]: 0:00:00.005057

# %% [markdown]
# Show P(F)

# %%
circuits.show_p_f(f_list,input_qubit_number,max_gate_number,batch_calculation_number)
